# %% [markdown]
# <h1> Cleaning Credit Card Data Set </h1>

# %% [markdown]
# <h3> Importing Libraries and Tools </h3>

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\ASUS\Documents\Skill Learning\Data Analyst Path\Data Source\Data Science with onur\credit_customers.csv")

data
# Out:
#     checking_status  duration                  credit_history  \
# 0                <0       6.0  critical/other existing credit
# 1          0<=X<200      48.0                   existing paid
# 2       no checking      12.0  critical/other existing credit
# 3                <0      42.0                   existing paid
# 4                <0      24.0              delayed previously
# ..              ...       ...                             ...
# 995     no checking      12.0                   existing paid
# 996              <0      30.0                   existing paid
# 997     no checking      12.0                   existing paid
# 998              <0      45.0                   existing paid
# 999        0<=X<200      45.0  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 0               radio/tv         1169.0  no known savings         >=7
# 1               radio/tv         5951.0              <100      1<=X<4
# ...

# %% [markdown]
# <h3> Quick Look </h3>

# %% [markdown]
# 1. Reducing columns?
# 2. duplicates?
# 3. missing values?
# 4. any formating issues?
# 5. data types?

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# checking_status           0
# duration                  0
# credit_history            0
# purpose                   0
# credit_amount             0
# savings_status            0
# employment                0
# installment_commitment    0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# housing                   0
# existing_credits          0
# job                       0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# dtype: int64

# %%
data
# Out:
#     checking_status  duration                  credit_history  \
# 0                <0       6.0  critical/other existing credit
# 1          0<=X<200      48.0                   existing paid
# 2       no checking      12.0  critical/other existing credit
# 3                <0      42.0                   existing paid
# 4                <0      24.0              delayed previously
# ..              ...       ...                             ...
# 995     no checking      12.0                   existing paid
# 996              <0      30.0                   existing paid
# 997     no checking      12.0                   existing paid
# 998              <0      45.0                   existing paid
# 999        0<=X<200      45.0  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 0               radio/tv         1169.0  no known savings         >=7
# 1               radio/tv         5951.0              <100      1<=X<4
# ...

# %%
data['residence_since'].value_counts()
# Out:
# residence_since
# 4.0    413
# 2.0    308
# 3.0    149
# 1.0    130
# Name: count, dtype: int64

# %% [markdown]
# <h3> Reducing unnecessary columns </h3>

# %%
data.columns
# Out:
# Index(['checking_status', 'duration', 'credit_history', 'purpose',
#        'credit_amount', 'savings_status', 'employment',
#        'installment_commitment', 'personal_status', 'other_parties',
#        'residence_since', 'property_magnitude', 'age', 'other_payment_plans',
#        'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        'foreign_worker', 'class'],
#       dtype='object')

# %%
data_continue = [
#'checking_status', 'duration', 'credit_history', 
    'purpose',
    'credit_amount', 
#'savings_status', 'employment', 'installment_commitment', 'personal_status', 'other_parties',
#'residence_since', 'property_magnitude', 
    'age', 'other_payment_plans',
       'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
       'foreign_worker', 'class'
]

data_delete = [
    'checking_status', 'duration', 'credit_history','savings_status', 
    'employment', 'installment_commitment', 'personal_status', 'other_parties',
    'residence_since', 'property_magnitude'
]

# %%
data.drop(columns=data_delete, inplace=True)

# %%
data
# Out:
#                  purpose  credit_amount   age other_payment_plans   housing  \
# 0               radio/tv         1169.0  67.0                none       own
# 1               radio/tv         5951.0  22.0                none       own
# 2              education         2096.0  49.0                none       own
# 3    furniture/equipment         7882.0  45.0                none  for free
# 4                new car         4870.0  53.0                none  for free
# ..                   ...            ...   ...                 ...       ...
# 995  furniture/equipment         1736.0  31.0                none       own
# 996             used car         3857.0  40.0                none       own
# 997             radio/tv          804.0  38.0                none       own
# 998             radio/tv         1845.0  23.0                none  for free
# 999             used car         4576.0  27.0                none       own
#
# ...

# %% [markdown]
# <h3> Removing Duplicates and Nulls </h3>

# %% [markdown]
# detected no nulls nor duplicates

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# purpose                0
# credit_amount          0
# age                    0
# other_payment_plans    0
# housing                0
# existing_credits       0
# job                    0
# num_dependents         0
# own_telephone          0
# foreign_worker         0
# class                  0
# dtype: int64

# %% [markdown]
# <h3> formating issues </h3>

# %%
#renaming columns/ campitalize the word
new_col = []

for pod in data.columns:
    new_col .append(pod.capitalize())

# %%
data.columns = new_col

# %%
data
# Out:
#                  Purpose  Credit_amount   Age Other_payment_plans   Housing  \
# 0               radio/tv         1169.0  67.0                none       own
# 1               radio/tv         5951.0  22.0                none       own
# 2              education         2096.0  49.0                none       own
# 3    furniture/equipment         7882.0  45.0                none  for free
# 4                new car         4870.0  53.0                none  for free
# ..                   ...            ...   ...                 ...       ...
# 995  furniture/equipment         1736.0  31.0                none       own
# 996             used car         3857.0  40.0                none       own
# 997             radio/tv          804.0  38.0                none       own
# 998             radio/tv         1845.0  23.0                none  for free
# 999             used car         4576.0  27.0                none       own
#
# ...

# %% [markdown]
# <h3> checking per column </h3>

# %%
data['Class'].value_counts()
# Out:
# Class
# good    700
# bad     300
# Name: count, dtype: int64

# %% [markdown]
# <h3> changing data types </h3>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Purpose              1000 non-null   object
#  1   Credit_amount        1000 non-null   float64
#  2   Age                  1000 non-null   float64
#  3   Other_payment_plans  1000 non-null   object
#  4   Housing              1000 non-null   object
#  5   Existing_credits     1000 non-null   float64
#  6   Job                  1000 non-null   object
#  7   Num_dependents       1000 non-null   float64
#  8   Own_telephone        1000 non-null   object
#  9   Foreign_worker       1000 non-null   object
#  10  Class                1000 non-null   object
# dtypes: float64(4), object(7)
# memory usage: 86.1+ KB

# %%
#data['Class'].value_counts()

data['Class'] = data['Class'].apply(lambda x: 1 if x == 'good' else 0)

# %%
data['Foreign_worker'].value_counts()

#data['Foreign_worker'] = data['Foreign_worker'].apply(lambda x: 1 if x == 'yes' else 0)
# Out:
# Foreign_worker
# 1    963
# 0     37
# Name: count, dtype: int64

# %% [markdown]
# <h3> some djustment </h3>

# %%
#data.drop(columns='Own_telephone', inplace=True)
data
# Out:
#                  Purpose  Credit_amount   Age Other_payment_plans   Housing  \
# 0               radio/tv         1169.0  67.0                none       own
# 1               radio/tv         5951.0  22.0                none       own
# 2              education         2096.0  49.0                none       own
# 3    furniture/equipment         7882.0  45.0                none  for free
# 4                new car         4870.0  53.0                none  for free
# ..                   ...            ...   ...                 ...       ...
# 995  furniture/equipment         1736.0  31.0                none       own
# 996             used car         3857.0  40.0                none       own
# 997             radio/tv          804.0  38.0                none       own
# 998             radio/tv         1845.0  23.0                none  for free
# 999             used car         4576.0  27.0                none       own
#
# ...

# %%
type(data['Existing_credits'][0])
# Out:
# numpy.float64

# %%
data['Existing_credits'].value_counts()
# Out:
# Existing_credits
# 1.0    633
# 2.0    333
# 3.0     28
# 4.0      6
# Name: count, dtype: int64

# %%
data['Existing_credits'] = data['Existing_credits'].astype(int)

# %% [markdown]
# <h3> Saving Cleaned Data </h3>

# %%
new_file = 'CCard_Cleaned_Data.CSV'

data.to_csv(rf"C:\Users\ASUS\Documents\Skill Learning\Data Analyst Path\Python\Learning Panda\Data Science with Onur\Cleaning Project\{new_file}", index=False)

print(f'file saved as : {new_file}')
# Out:
# file saved as : CCard_Cleaned_Data.CSV
